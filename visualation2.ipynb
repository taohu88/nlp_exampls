# %%
from sklearn import datasets
import hypertools as hyp
import matplotlib.pyplot as plt
# %matplotlib inline  


digits = datasets.load_digits(n_class=6)
data = digits.data
group = digits.target.astype('str')

hyp.plot(data, '.', model='TSNE', group=group, ndims=2)
# Out:
# (<matplotlib.figure.Figure at 0x7fc51c60ffd0>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7fc517432400>,
#  [array([[  5.36747522,  17.06673351],
#          [  6.45336683, -14.08036945],
#          [ 12.65200027,   1.31579399],
#          ...,
#          [ -3.75108142,  11.82327773],
#          [ -4.4547712 ,   9.90987077],
#          [ 11.09742362,  18.01777042]])],
#  None)
